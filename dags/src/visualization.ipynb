# %%
import pandas as pd
import plotly.express as px

# %%
from pathlib import Path

# Get the current working directory
current_working_directory = Path.cwd()

current_working_directory
# Out:
# WindowsPath('f:/Projects/YoutubeTest/dags/src')

# %%
df = pd.read_csv("../../Results/trendOfVideosEachChannelAYear.csv")

# %%
# Convert 'published_at' to datetime
df['published_at'] = pd.to_datetime(df['published_at'])

# %%
df
# Out:
#                                             video_title        published_at  \
# 0                           “Girl Math” Masuk akal Tak? 2023-11-28 11:03:37
# 1     #NoTapis - Konflik Israel-Palestin: Respons & ... 2023-11-27 18:38:18
# 2     ‘Kami Okami nak bantu anak muda lain berdaya m... 2023-11-25 13:16:46
# 3           Kaki Makan: 4 Gerai Nasi Lemak untuk Dicuba 2023-11-25 12:12:17
# 4     Kaki Makan: Burger tanduri jadi pilihan pasang... 2023-11-18 13:55:40
# ...                                                 ...                 ...
# 2319  【世界大解说】财富以外 高净值人士扎根狮城  回馈社会  What do high-net-... 2023-06-04 09:00:29
# 2320                                    玛娃台风临近日本  数千人疏散 2023-06-03 18:05:21
# 2321  新山暴雨来袭导致餐馆淹水 逾10人被困近两个小时 https://bit.ly/3u4cVZ... 2023-11-09 16:52:52
# 2322  二战后，新加坡华文报主笔用社论救人性命 https://bit.ly/463rolM #br... 2023-11-09 16:30:03
# 2323                            【新闻抢先看】脚车停地铁站外 被拖走罚款30元 2023-11-08 17:31:07
#
# ...

# %%
fig = px.scatter(df, x='published_at', y='views_count',facet_col="channel_title", title='Views over time')
fig.update_xaxes(rangeslider_visible=True)
fig.update_yaxes(autorange = True)
fig.update_layout(xaxis_title='Date', yaxis_title='Number of active cases')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File f:\Projects\YoutubeTest\.venv\lib\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File f:\Projects\YoutubeTest\.venv\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File f:\Projects\YoutubeTest\.venv\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
# ...
